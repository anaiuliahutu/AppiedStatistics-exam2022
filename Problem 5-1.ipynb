# %%
#Problem 5.1
import math
import numpy as np
import scipy.stats as stats
import pandas as pd

# %%
df = pd.read_csv('data_GlacierSizes.csv', header=0)
Area, sigArea, Volume, SigVolume=df.values.T
df.plot(x=' Area', y=' Volume', kind='kde', xlabel='Area')
# Out:
# <AxesSubplot: ylabel='Density'>
